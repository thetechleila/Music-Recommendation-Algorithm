# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %% [markdown]
# ___
#
# # Music Recommendation Training Dataset Overview
#
# ___

# %%
#Store music recommendation training dataset file path in variable for readability
train_path = ("/Users/sa14/Desktop/Music Recommendation Algorithm with Unsupervised Learning/data/music_rec_trainset.csv")

#Load music recommendation training dataset csv as a dataframe
df = pd.read_csv(train_path)

# %%
#Get the first 10 rows of the music recommendation training dataframe
df.head(10)
# Out:
#    Unnamed: 0           artist_name  \
# 0           0                mukesh
# 1           4         frankie laine
# 2           6           johnnie ray
# 3          10           pérez prado
# 4          12  giorgos papadopoulos
# 5          14            perry como
# 6          15             freestyle
# 7          17         johnny mathis
# 8          20   stélios kazantzídis
# 9          23   stélios kazantzídis
#
#                                           track_name  release_date genre  \
# 0                               mohabbat bhi jhoothi          1950   pop
# 1                                          i believe          1950   pop
# 2                                                cry          1950   pop
# 3                                           patricia          1950   pop
# 4                                 apopse eida oneiro          1950   pop
# 5  round and round (with mitchell ayres and his o...          1950   pop
# 6                         opm medley: when i met you          1950   pop
# 7                             it's not for me to say          1950   pop
# 8                           klapse me mana klapse me          1950   pop
# 9                                  finito la mouzika          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
# 5  convoy light dead ahead merchantmen trump dies...   98  0.001053  0.420685
# 6  piece mindin world knowin life come bring give...  179  0.000483  0.000483
# 7  care moment hold fast press lips dream heaven ...   21  0.002506  0.002506
# 8  lonely night surround power read mind hour nig...   30  0.083537  0.002024
# 9  tear heart seat stay awhile tear heart game st...   61  0.001120  0.102548
#
#    world/life  ...  communication   obscene     music  movement/places  \
# 0    0.000598  ...       0.263751  0.000598  0.039288         0.000598
# 1    0.443435  ...       0.001284  0.001284  0.118034         0.001284
# 2    0.002770  ...       0.250668  0.002770  0.323794         0.002770
# 3    0.001548  ...       0.001548  0.001548  0.001548         0.129250
# 4    0.417772  ...       0.001350  0.001350  0.001350         0.001350
# 5    0.001053  ...       0.001053  0.001053  0.001053         0.001053
# 6    0.371817  ...       0.384703  0.000483  0.000483         0.000483
# 7    0.336056  ...       0.002506  0.002506  0.002506         0.002506
# 8    0.002024  ...       0.167783  0.002024  0.002024         0.002024
# 9    0.001120  ...       0.091572  0.001120  0.001120         0.105752
#
#    light/visual perceptions  family/spiritual   sadness  feelings       topic  \
# 0                  0.000598          0.000598  0.380299  0.117175     sadness
# 1                  0.212681          0.051124  0.001284  0.001284  world/life
# 2                  0.002770          0.002770  0.002770  0.225422       music
# 3                  0.001548          0.001548  0.225889  0.001548    romantic
# 4                  0.001350          0.029755  0.068800  0.001350    romantic
# 5                  0.172173          0.001053  0.128292  0.001053    violence
# 6                  0.044355          0.000483  0.000483  0.123150  world/life
# 7                  0.386887          0.002506  0.062602  0.002506  world/life
# 8                  0.002024          0.002024  0.002024  0.031600    romantic
# 9                  0.001120          0.001120  0.630507  0.001120     sadness
#
#    age
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0
# 5  1.0
# 6  1.0
# 7  1.0
# 8  1.0
# 9  1.0
#
# [10 rows x 24 columns]

# %%
#Remove "Unnamed:0" column from dataframe
df.drop(df.filter(regex="Unnamed").columns, axis=1, inplace=True)

#Verify "Unnamed:0" column removal
df.head()
# Out:
#             artist_name            track_name  release_date genre  \
# 0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1         frankie laine             i believe          1950   pop
# 2           johnnie ray                   cry          1950   pop
# 3           pérez prado              patricia          1950   pop
# 4  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
#    world/life  night/time  ...  communication   obscene     music  \
# 0    0.000598    0.000598  ...       0.263751  0.000598  0.039288
# 1    0.443435    0.001284  ...       0.001284  0.001284  0.118034
# 2    0.002770    0.002770  ...       0.250668  0.002770  0.323794
# 3    0.001548    0.001548  ...       0.001548  0.001548  0.001548
# 4    0.417772    0.001350  ...       0.001350  0.001350  0.001350
#
#    movement/places  light/visual perceptions  family/spiritual   sadness  \
# 0         0.000598                  0.000598          0.000598  0.380299
# 1         0.001284                  0.212681          0.051124  0.001284
# 2         0.002770                  0.002770          0.002770  0.002770
# 3         0.129250                  0.001548          0.001548  0.225889
# 4         0.001350                  0.001350          0.029755  0.068800
#
#    feelings       topic  age
# 0  0.117175     sadness  1.0
# 1  0.001284  world/life  1.0
# 2  0.225422       music  1.0
# 3  0.001548    romantic  1.0
# 4  0.001350    romantic  1.0
#
# [5 rows x 23 columns]

# %%
#Get the count of rows and columns for the dataset
df.shape
# Out:
# (28362, 23)

# %% [markdown]
# **This dataset has 28,362 rows and 23 columns after removing the "Unnamed: 0" column**

# %%
#Get overall count of null/NaN values in the dataset
null_count = df.isnull().sum()
print("Null Values by Column \n",null_count)
# Out:
# Null Values by Column
#  artist_name                 0
# track_name                  0
# release_date                0
# genre                       0
# lyrics                      0
# len                         0
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# sadness                     0
# feelings                    0
# topic                       0
# age                         0
# dtype: int64

# %% [markdown]
# **No null values exist across this entire dataset.**

# %%
#Get column data types (dtype), overall count of each present dtype, and memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28362 entries, 0 to 28361
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   artist_name               28362 non-null  object
#  1   track_name                28362 non-null  object
#  2   release_date              28362 non-null  int64
#  3   genre                     28362 non-null  object
#  4   lyrics                    28362 non-null  object
#  5   len                       28362 non-null  int64
#  6   dating                    28362 non-null  float64
#  7   violence                  28362 non-null  float64
#  8   world/life                28362 non-null  float64
#  9   night/time                28362 non-null  float64
#  10  shake the audience        28362 non-null  float64
#  11  family/gospel             28362 non-null  float64
#  12  romantic                  28362 non-null  float64
#  13  communication             28362 non-null  float64
#  14  obscene                   28362 non-null  float64
#  15  music                     28362 non-null  float64
#  16  movement/places           28362 non-null  float64
#  17  light/visual perceptions  28362 non-null  float64
#  18  family/spiritual          28362 non-null  float64
#  19  sadness                   28362 non-null  float64
#  20  feelings                  28362 non-null  float64
#  21  topic                     28362 non-null  object
#  22  age                       28362 non-null  float64
# dtypes: float64(16), int64(2), object(5)
# memory usage: 5.0+ MB

# %%
#Determine the descriptive statistics of the dataset such as the mean, median, percentiles, etc.
df.describe()
# Out:
#        release_date           len        dating      violence    world/life  \
# count  28362.000000  28362.000000  28362.000000  28362.000000  28362.000000
# mean    1990.239652     73.030534      0.021110      0.118371      0.120984
# std       18.486997     41.831605      0.052366      0.178658      0.172216
# min     1950.000000      1.000000      0.000291      0.000284      0.000291
# 25%     1975.000000     42.000000      0.000923      0.001120      0.001170
# 50%     1991.000000     63.000000      0.001462      0.002506      0.006579
# 75%     2007.000000     93.000000      0.004049      0.192538      0.197854
# max     2019.000000    199.000000      0.647706      0.981781      0.962105
#
#          night/time  shake the audience  family/gospel      romantic  \
# count  28362.000000        28362.000000   28362.000000  28362.000000
# mean       0.057356            0.017418       0.017045      0.048676
# std        0.111892            0.040658       0.041968      0.106071
# min        0.000289            0.000284       0.000289      0.000284
# 25%        0.001032            0.000993       0.000923      0.000975
# 50%        0.001949            0.001595       0.001504      0.001754
# 75%        0.065778            0.009989       0.004785      0.042304
# max        0.973684            0.497463       0.545303      0.940789
#
#        communication       obscene         music  movement/places  \
# count   28362.000000  28362.000000  28362.000000     28362.000000
# mean        0.076651      0.097185      0.060067         0.047417
# std         0.109497      0.181314      0.123346         0.091559
# min         0.000291      0.000289      0.000289         0.000284
# 25%         0.001144      0.001053      0.000975         0.000993
# 50%         0.002632      0.001815      0.001815         0.001645
# 75%         0.132111      0.088799      0.055109         0.054373
# max         0.645829      0.992298      0.956938         0.638021
#
#        light/visual perceptions  family/spiritual       sadness      feelings  \
# count              28362.000000      28362.000000  28362.000000  28362.000000
# mean                   0.049008          0.024155      0.129402      0.030995
# std                    0.089553          0.051032      0.181149      0.071656
# min                    0.000284          0.000284      0.000284      0.000289
# 25%                    0.000993          0.000957      0.001144      0.000993
# 50%                    0.001815          0.001645      0.005263      0.001754
# 75%                    0.064302          0.025515      0.235115      0.032617
# max                    0.667782          0.618073      0.981424      0.958810
#
#                 age
# count  28362.000000
# mean       0.425148
# std        0.264100
# min        0.014286
# 25%        0.185714
# 50%        0.414286
# 75%        0.642857
# max        1.000000

# %%
#Check for duplicate entries, get count of duplicates, then store in variable
duplicate_counts = df.value_counts()
duplicate_count = duplicate_counts[duplicate_counts > 1].sum()
print(duplicate_count)
# Out:
# 0

# %% [markdown]
# **This dataset does not contain any duplicate values.**

# %% [markdown]
# ___
#
# ## Univariate Analysis
# ___

# %% [markdown]
# > ### Pre-Exisiting Info About the *"release_date"* Column
# >
# >> The year the song was released expressed as a 4 digit integer.

# %%
#Inspect "release date" column by getting count of unique values
df["release_date"].value_counts(ascending=True)

#It seems as though the amount of releases may increase every year from 1953 to 2017
# Out:
# release_date
# 1953     48
# 1950     51
# 1951     58
# 1952     59
# 1955    106
#        ...
# 2012    588
# 2009    596
# 2015    617
# 2018    653
# 2017    660
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# **The dataset spans 70 years, 1950 - 2017**

# %%
#Group the release dates and song counts by decade using floor division for understandability
release_count_dec = df["release_date"]//10*10

#Get count of songs sorted by decade
release_count_dec.value_counts()
# Out:
# release_date
# 2010    5631
# 2000    4779
# 1980    4674
# 1990    4454
# 1970    3950
# 1960    3407
# 1950    1467
# Name: count, dtype: int64

# %%
#Visualize the count of songs by year in a histplot
sns.histplot(data = df, x = "release_date", color="pink", edgecolor ='black', linewidth= 1)
plt.title("Count of Songs in the Dataset from 1950-2017")
plt.xlabel("Song Release Year")
plt.ylabel("Amount of Songs")
plt.show()

# %%
sns.histplot(data = release_count_dec, color="green", edgecolor ='black', linewidth= 1)
plt.title("Count of Songs in the Dataset Released by Decade 1950-2020")
plt.xlabel("Dataset Song Release Decade")
plt.ylabel("Song Count")
plt.show()

# %% [markdown]
# ___
#
# > ### *Insights* from the Univariate Analysis of the "release_date" Column: *Insights*
# ___
# >
# > * The 2010s have the highest count of songs released in the dataset. There is a very noticeable visable sharp spike in song releases present in both release_date column graphs.
# >   * As was uncovered in the examination of the column's unique value counts:
#   | Release Year | Amount of Songs|
# | -------- | ------- |
# | 2009     | 596     |
# | 2012     | 588     |
# | 2015     | 617     |
# | 2017     | 660     |
# >
# | Release Year | Amount of Songs|
# | -------- | ------- |
# | 1950     |  51     |
# | 1951     |  58     |
# | 1952     |  59     |
# | 1953     |  48     |
# | 1955     | 106     |
# > * There is a significant increase between the starting year of 1950 and the latter years of the dataset approaching 2020.
